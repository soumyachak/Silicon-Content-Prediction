# %%
from sklearn.model_selection import GridSearchCV, KFold
from xgboost import XGBRegressor
import pandas as pd

# %%
# Importing data
df = pd.read_csv("anomaly_removed.csv")
df.head(2)
# Out:
#                  Timestamp    OxEnRa   BlFuPeIn        EnOxFl     CoBlFl  \
# 0  2021-05-12 17:56:25.000  3.691772  17.661523  16941.904350  36.472670
# 1  2021-05-12 17:56:25.000  3.744628   0.193811  17554.954071  34.087434
#
#          BlMo   BlFuBoGaVo  BlFuBoGaIn       ThCoTe      ToGaPr  ...  \
# 0  146.285825  7925.957227   81.975757  2210.712256  224.366480  ...
# 1  161.762571  8049.518860   81.637472  2268.780322    0.005692  ...
#
#        CoBlTe       HoBlTe     ToTe       BlHu   CoInSeVa      FoSI  \
# 0  212.936183  1087.730999  1.79588  13.118669  45.994059  0.481272
# 1  213.288686     2.082851  1.79588  10.353929   1.580861  0.337968
#
#           HoBl      ToGasP       CoBF        SI
# 0  1075.254532  221.600735  36.796521  0.479000
# 1     2.110829    0.005584  34.238289  0.312456
#
# [2 rows x 25 columns]

# %%
df.shape
# Out:
# (5366, 25)

# %%
# Using grid search to determine the best parameters

X, y = df.iloc[:,1:-1].values, df.iloc[:,-1].values

xgb = XGBRegressor(objective='reg:squarederror', random_state=42)

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.8, 1.0],
    'gamma': [0.3, 0.5, 1]
}

kfold = KFold(n_splits=10, shuffle=True, random_state=42)

grid_search = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=kfold,
    verbose=3,
    n_jobs=-1
)

grid_search.fit(X, y)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     imp...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'gamma': [0.3, 0.5, 1], 'learning_rate': [0.01, 0.1],
#                          'max_depth': [3, 5, 7], 'n_estimators': [50, 100, 150],
#                          'subsample': [0.8, 1.0]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
# Best parameters and score
print("Best Parameters:", grid_search.best_params_)
print("Best Score (MSE):", -grid_search.best_score_)
# Out:
# Best Parameters: {'gamma': 0.3, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.8}
# Best Score (MSE): 0.007281271716580715
